# %% [markdown]
# Pandas Library
#
# EDA - Exploratory Data Analysis

# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 2.2.2

# %%
# Pandas Series  from list
# single dimensional data
accno=[1212,2333,4555,6666]
ser=pd.Series(accno)
print(ser)
# Out:
# 0    1212
# 1    2333
# 2    4555
# 3    6666
# dtype: int64

# %%
# pandas series from dictionary
temperature={"london":14,"scotland":12,"liverpool":11}
city_temp=pd.Series(temperature)
print(city_temp)
# Out:
# london       14
# scotland     12
# liverpool    11
# dtype: int64

# %%
# dataframe
from google.colab import files
d=files.upload()
# Out:
#      <input type="file" id="files-52048943-64cc-42d7-9aca-328662832c26" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-52048943-64cc-42d7-9aca-328662832c26">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# csv comma separated values
df_h=pd.read_csv('diabetes.csv')
df_h
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
dfh1=df_h.copy()

# %%
dfh1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# columns - features

# %% [markdown]
# EDA

# %%
df_h.shape # number of rows and columns
# Out:
# (768, 9)

# %%
df_h.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df_h.size # total number of data
# Out:
# 6912

# %%
df_h.info() # datatypes, null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
# shows basic statistics
df_h.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df_h.head() # first 5 records
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df_h.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %%
df_h.head(100)
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             6      148             72             35        0  33.6
# 1             1       85             66             29        0  26.6
# 2             8      183             64              0        0  23.3
# 3             1       89             66             23       94  28.1
# 4             0      137             40             35      168  43.1
# ..          ...      ...            ...            ...      ...   ...
# 95            6      144             72             27      228  33.9
# 96            2       92             62             28        0  31.6
# 97            1       71             48             18       76  20.4
# 98            6       93             50             30       64  28.7
# 99            1      122             90             51      220  49.7
#
#     DiabetesPedigreeFunction  Age  Outcome
# 0                      0.627   50        1
# ...

# %%
df_h.tail( ) # last 5 rows
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df_h.tail(15)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 753            0      181             88             44      510  43.3
# 754            8      154             78             32        0  32.4
# 755            1      128             88             39      110  36.5
# 756            7      137             90             41        0  32.0
# 757            0      123             72              0        0  36.3
# 758            1      106             76              0        0  37.5
# 759            6      190             92              0        0  35.5
# 760            2       88             58             26       16  28.4
# 761            9      170             74             31        0  44.0
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# ...

# %%
df_h.tail(1000)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df_h
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
# any data is empty
df_h.isnull()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0          False    False          False          False    False  False
# 1          False    False          False          False    False  False
# 2          False    False          False          False    False  False
# 3          False    False          False          False    False  False
# 4          False    False          False          False    False  False
# ..           ...      ...            ...            ...      ...    ...
# 763        False    False          False          False    False  False
# 764        False    False          False          False    False  False
# 765        False    False          False          False    False  False
# 766        False    False          False          False    False  False
# 767        False    False          False          False    False  False
#
#      DiabetesPedigreeFunction    Age  Outcome
# 0                       False  False    False
# ...

# %%
df_h.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# # Feature Engineering or Feature Extraction

# %%
# to retrieve particular column
df_h['BMI']
# Out:
# 0      33.6
# 1      26.6
# 2      23.3
# 3      28.1
# 4      43.1
#        ...
# 763    32.9
# 764    36.8
# 765    26.2
# 766    30.1
# 767    30.4
# Name: BMI, Length: 768, dtype: float64

# %%
# filteration
df_h['BMI']>35
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 763    False
# 764     True
# 765    False
# 766    False
# 767    False
# Name: BMI, Length: 768, dtype: bool

# %%
df_h=df_h[(df_h['BMI']>35) | (df_h['Glucose'] > 100)]
df_h
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 2              8      183             64              0        0  23.3
# 4              0      137             40             35      168  43.1
# 5              5      116             74              0        0  25.6
# 7             10      115              0              0        0  35.3
# ..           ...      ...            ...            ...      ...   ...
# 761            9      170             74             31        0  44.0
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
# specific column as data frames
df_h[['BMI']]
# Out:
#       BMI
# 0    33.6
# 2    23.3
# 4    43.1
# 5    25.6
# 7    35.3
# ..    ...
# 761  44.0
# 763  32.9
# 764  36.8
# 765  26.2
# 766  30.1
#
# [610 rows x 1 columns]

# %%
df_h[['BMI',"Age"]]
# Out:
#       BMI  Age
# 0    33.6   50
# 2    23.3   32
# 4    43.1   33
# 5    25.6   30
# 7    35.3   29
# ..    ...  ...
# 761  44.0   43
# 763  32.9   63
# 764  36.8   27
# 765  26.2   30
# 766  30.1   47
#
# [610 rows x 2 columns]

# %%
df_h.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df_h[['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI', 'Age']]
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin   BMI  Age
# 0        148             72             35        0  33.6   50
# 2        183             64              0        0  23.3   32
# 4        137             40             35      168  43.1   33
# 5        116             74              0        0  25.6   30
# 7        115              0              0        0  35.3   29
# ..       ...            ...            ...      ...   ...  ...
# 761      170             74             31        0  44.0   43
# 763      101             76             48      180  32.9   63
# 764      122             70             27        0  36.8   27
# 765      121             72             23      112  26.2   30
# 766      126             60              0        0  30.1   47
#
# [610 rows x 6 columns]

# %% [markdown]
# Indicator variables - present or absent
#
# add a feature

# %%
import numpy as np
df_h['result']=np.where(df_h['BloodPressure']>70,1,0)
# Out:
# <ipython-input-30-79395677c23d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_h['result']=np.where(df_h['BloodPressure']>70,1,0)

# %%
df_h
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 2              8      183             64              0        0  23.3
# 4              0      137             40             35      168  43.1
# 5              5      116             74              0        0  25.6
# 7             10      115              0              0        0  35.3
# ..           ...      ...            ...            ...      ...   ...
# 761            9      170             74             31        0  44.0
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome  result
# 0                       0.627   50        1       1
# ...

# %% [markdown]
# Extracting rows
#
# loc - locates row by name ,iloc -number - slice

# %%
dfh1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
dfh1.iloc[10:15] # specific rows 10,11,12,13,14
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 10            4      110             92              0        0  37.6
# 11           10      168             74              0        0  38.0
# 12           10      139             80              0        0  27.1
# 13            1      189             60             23      846  30.1
# 14            5      166             72             19      175  25.8
#
#     DiabetesPedigreeFunction  Age  Outcome
# 10                     0.191   30        0
# 11                     0.537   34        1
# 12                     1.441   57        0
# 13                     0.398   59        1
# 14                     0.587   51        1

# %%
# specific rows and column
dfh1.iloc[10:15][['Glucose','BloodPressure','SkinThickness','Insulin','BMI']]
# Out:
#     Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 10      110             92              0        0  37.6
# 11      168             74              0        0  38.0
# 12      139             80              0        0  27.1
# 13      189             60             23      846  30.1
# 14      166             72             19      175  25.8

# %%
# all rows and 2nd col
dfh1.iloc[:,[2]]
# Out:
#      BloodPressure
# 0               72
# 1               66
# 2               64
# 3               66
# 4               40
# ..             ...
# 763             76
# 764             70
# 765             72
# 766             60
# 767             70
#
# [768 rows x 1 columns]

# %%
# all rows ,col 2,3,4,5
dfh1.iloc[:,2:6]
# Out:
#      BloodPressure  SkinThickness  Insulin   BMI
# 0               72             35        0  33.6
# 1               66             29        0  26.6
# 2               64              0        0  23.3
# 3               66             23       94  28.1
# 4               40             35      168  43.1
# ..             ...            ...      ...   ...
# 763             76             48      180  32.9
# 764             70             27        0  36.8
# 765             72             23      112  26.2
# 766             60              0        0  30.1
# 767             70             31        0  30.4
#
# [768 rows x 4 columns]

# %%
# specific rows and cols
dfh1.iloc[20:31,2:6]
# Out:
#     BloodPressure  SkinThickness  Insulin   BMI
# 20             88             41      235  39.3
# 21             84              0        0  35.4
# 22             90              0        0  39.8
# 23             80             35        0  29.0
# 24             94             33      146  36.6
# 25             70             26      115  31.1
# 26             76              0        0  39.4
# 27             66             15      140  23.2
# 28             82             19      110  22.2
# 29             92              0        0  34.1
# 30             75             26        0  36.0

# %% [markdown]
# # Data cleaning
#
# check missing value
#
# check duplicates

# %%
# handling missing data
#Import the libraries

import pandas as pd

# Create a CSV dataset
# NaN empty values
employee = '''ID,Name,Gender,Salary,City,Company
1,Ravi,Male,35000,Chennai,tcs
2,Radha,Female,45000,trichy,NaN
3,viji,Female,25000,coimbatore,cts
4,vikram,NaN,NaN,bombay,tcs
5,vijay,Male,NaN,bombay,cts
6,anbu,Male,54000,NaN,wipro
7,anu,NaN,74000,Chennai,NaN
8,bala,Male,14000,goa,wipro
9,banu,Female,15000,bangalore,wipro
10,raja,Male,33000,hyderabad,NaN'''


with open('salary.csv', 'w') as out:
    out.write(employee)


# Import the dataset
df_emp = pd.read_csv('/content/salary.csv')
print('Salary Dataset: \n', df_emp)
# Out:
# Salary Dataset:
#     ID    Name  Gender   Salary        City Company
# 0   1    Ravi    Male  35000.0     Chennai     tcs
# 1   2   Radha  Female  45000.0      trichy     NaN
# 2   3    viji  Female  25000.0  coimbatore     cts
# 3   4  vikram     NaN      NaN      bombay     tcs
# 4   5   vijay    Male      NaN      bombay     cts
# 5   6    anbu    Male  54000.0         NaN   wipro
# 6   7     anu     NaN  74000.0     Chennai     NaN
# 7   8    bala    Male  14000.0         goa   wipro
# 8   9    banu  Female  15000.0   bangalore   wipro
# 9  10    raja    Male  33000.0   hyderabad     NaN

# %%
# missing values
df_emp.isna()
# Out:
#       ID   Name  Gender  Salary   City  Company
# 0  False  False   False   False  False    False
# 1  False  False   False   False  False     True
# 2  False  False   False   False  False    False
# 3  False  False    True    True  False    False
# 4  False  False   False    True  False    False
# 5  False  False   False   False   True    False
# 6  False  False    True   False  False     True
# 7  False  False   False   False  False    False
# 8  False  False   False   False  False    False
# 9  False  False   False   False  False     True

# %%
df_emp.isnull()
# Out:
#       ID   Name  Gender  Salary   City  Company
# 0  False  False   False   False  False    False
# 1  False  False   False   False  False     True
# 2  False  False   False   False  False    False
# 3  False  False    True    True  False    False
# 4  False  False   False    True  False    False
# 5  False  False   False   False   True    False
# 6  False  False    True   False  False     True
# 7  False  False   False   False  False    False
# 8  False  False   False   False  False    False
# 9  False  False   False   False  False     True

# %%
df_emp.isnull().sum()
# Out:
# ID         0
# Name       0
# Gender     2
# Salary     2
# City       1
# Company    3
# dtype: int64

# %% [markdown]
# how to deal
#
# drop row
#
# fill row -
#
# int,float - mean, median
#
# string - mode - repeated

# %%
df_emp.isnull().any()
# Out:
# ID         False
# Name       False
# Gender      True
# Salary      True
# City        True
# Company     True
# dtype: bool

# %% [markdown]
# Data imputation
#
# filling missing values
#
# fillna()
#
# dropna()
#
# isna()

# %%
df_emp
# Out:
#    ID    Name  Gender   Salary        City Company
# 0   1    Ravi    Male  35000.0     Chennai     tcs
# 1   2   Radha  Female  45000.0      trichy     NaN
# 2   3    viji  Female  25000.0  coimbatore     cts
# 3   4  vikram     NaN      NaN      bombay     tcs
# 4   5   vijay    Male      NaN      bombay     cts
# 5   6    anbu    Male  54000.0         NaN   wipro
# 6   7     anu     NaN  74000.0     Chennai     NaN
# 7   8    bala    Male  14000.0         goa   wipro
# 8   9    banu  Female  15000.0   bangalore   wipro
# 9  10    raja    Male  33000.0   hyderabad     NaN

# %%
14000,15000,25000,33000,35000,45000,54000,74000
# Out:
# (14000, 15000, 25000, 33000, 35000, 45000, 54000, 74000)

# %%
df_emp['Company'].mode()
# Out:
# 0    wipro
# Name: Company, dtype: object

# %%
df_emp['Company']=df_emp['Company'].fillna(df_emp['Company'].mode()[0])
df_emp
# Out:
#    ID    Name  Gender   Salary        City Company
# 0   1    Ravi    Male  35000.0     Chennai     tcs
# 1   2   Radha  Female  45000.0      trichy   wipro
# 2   3    viji  Female  25000.0  coimbatore     cts
# 3   4  vikram     NaN      NaN      bombay     tcs
# 4   5   vijay    Male      NaN      bombay     cts
# 5   6    anbu    Male  54000.0         NaN   wipro
# 6   7     anu     NaN  74000.0     Chennai   wipro
# 7   8    bala    Male  14000.0         goa   wipro
# 8   9    banu  Female  15000.0   bangalore   wipro
# 9  10    raja    Male  33000.0   hyderabad   wipro

# %%
# median
df_emp['Salary']=df_emp['Salary'].fillna(df_emp['Salary'].median())
df_emp
# Out:
#    ID    Name  Gender   Salary        City Company
# 0   1    Ravi    Male  35000.0     Chennai     tcs
# 1   2   Radha  Female  45000.0      trichy   wipro
# 2   3    viji  Female  25000.0  coimbatore     cts
# 3   4  vikram     NaN  34000.0      bombay     tcs
# 4   5   vijay    Male  34000.0      bombay     cts
# 5   6    anbu    Male  54000.0         NaN   wipro
# 6   7     anu     NaN  74000.0     Chennai   wipro
# 7   8    bala    Male  14000.0         goa   wipro
# 8   9    banu  Female  15000.0   bangalore   wipro
# 9  10    raja    Male  33000.0   hyderabad   wipro

# %%
df_emp1=df_emp.dropna()
df_emp1
# Out:
#    ID   Name  Gender   Salary        City Company
# 0   1   Ravi    Male  35000.0     Chennai     tcs
# 1   2  Radha  Female  45000.0      trichy   wipro
# 2   3   viji  Female  25000.0  coimbatore     cts
# 4   5  vijay    Male  34000.0      bombay     cts
# 7   8   bala    Male  14000.0         goa   wipro
# 8   9   banu  Female  15000.0   bangalore   wipro
# 9  10   raja    Male  33000.0   hyderabad   wipro

# %%
df_emp
# Out:
#    ID    Name  Gender   Salary        City Company
# 0   1    Ravi    Male  35000.0     Chennai     tcs
# 1   2   Radha  Female  45000.0      trichy   wipro
# 2   3    viji  Female  25000.0  coimbatore     cts
# 3   4  vikram     NaN  34000.0      bombay     tcs
# 4   5   vijay    Male  34000.0      bombay     cts
# 5   6    anbu    Male  54000.0         NaN   wipro
# 6   7     anu     NaN  74000.0     Chennai   wipro
# 7   8    bala    Male  14000.0         goa   wipro
# 8   9    banu  Female  15000.0   bangalore   wipro
# 9  10    raja    Male  33000.0   hyderabad   wipro

# %%
df_emp['Name']=df_emp['Name'].str.capitalize()
df_emp
# Out:
#    ID    Name  Gender   Salary        City Company
# 0   1    Ravi    Male  35000.0     Chennai     tcs
# 1   2   Radha  Female  45000.0      trichy   wipro
# 2   3    Viji  Female  25000.0  coimbatore     cts
# 3   4  Vikram     NaN  34000.0      bombay     tcs
# 4   5   Vijay    Male  34000.0      bombay     cts
# 5   6    Anbu    Male  54000.0         NaN   wipro
# 6   7     Anu     NaN  74000.0     Chennai   wipro
# 7   8    Bala    Male  14000.0         goa   wipro
# 8   9    Banu  Female  15000.0   bangalore   wipro
# 9  10    Raja    Male  33000.0   hyderabad   wipro

# %%
df_emp['Company'].duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# Name: Company, dtype: bool

# %%
df_emp['City'].duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# 6     True
# 7    False
# 8    False
# 9    False
# Name: City, dtype: bool

# %%
# Create Dummy variables
loan = ['Yes', 'No', np.nan]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0ebcf72928b4> in <cell line: 0>()
#       1 # Create Dummy variables
# ----> 2 loan = ['Yes', 'No', np.nan]
#
# NameError: name 'np' is not defined

# %%
pd.get_dummies(loan)
# Out:
#       No    Yes
# 0  False   True
# 1   True  False
# 2  False  False

# %%
from google.colab import files
up=files.upload()
# Out:
#      <input type="file" id="files-11ecd46e-4c46-46c2-a4a4-64499499426f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-11ecd46e-4c46-46c2-a4a4-64499499426f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
dftit=pd.read_csv('Titanic_ds.csv')

# %%
pd.get_dummies(dftit)
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare  \
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ..           ...       ...     ...   ...    ...    ...      ...
# 886          887         0       2  27.0      0      0  13.0000
# 887          888         1       1  19.0      0      0  30.0000
# 888          889         0       3   NaN      1      2  23.4500
# 889          890         1       1  26.0      0      0  30.0000
# 890          891         0       3  32.0      0      0   7.7500
#
#      Name_Abbing, Mr. Anthony  Name_Abbott, Mr. Rossmore Edward  \
# 0                       False                             False
# 1                       False                             False
# ...

# %%
pd.get_dummies(dftit['Pclass'])
# Out:
#          1      2      3
# 0    False  False   True
# 1     True  False  False
# 2    False  False   True
# 3     True  False  False
# 4    False  False   True
# ..     ...    ...    ...
# 886  False   True  False
# 887   True  False  False
# 888  False  False   True
# 889   True  False  False
# 890  False  False   True
#
# [891 rows x 3 columns]
